# %% [markdown]
# # Getting and Knowing your Data
#
# In this assignment, we keep practicing `pandas` skills.
#
# # Exercise 1 (2 points)
#
# Import the `pandas` and `numpy` libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Exercise 2 (2 points)
#
# Create a data-frame called `users` and use `user_id` as index.

# %%
#Open csv file users.csv but setting the delimiter to being pipe '|' character.
users = pd.read_csv('users.csv', sep ='|', index_col = "user_id")

# %% [markdown]
# # Exercise 3 (2 points)
#
# Print the first 25 rows from the `users` data-frame.

# %%
users.head(25)
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other    06405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer    06355
# 18        35      F          other    37212
# 19        40      M      librarian    02138
# 20        42      F      homemaker    95660
# ...

# %% [markdown]
# # Exercise 4 (2 points)
#
# Print the last 10 rows from the `users` data-frame.

# %%
users.tail(10)
# Out:
#          age gender     occupation zip_code
# user_id
# 934       61      M       engineer    22902
# 935       42      M         doctor    66221
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 938       38      F     technician    55038
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841

# %% [markdown]
# # Exercise 5 (2 points)
#
# Report the number of rows and columns in the `users` data-frame.

# %%
users.shape
# Out:
# (943, 4)

# %% [markdown]
# # Exercise 6 (2 points)
#
# Report the data type of each column.

# %%
users.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 943 entries, 1 to 943
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         943 non-null    int64
#  1   gender      943 non-null    str
#  2   occupation  943 non-null    str
#  3   zip_code    943 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 29.6 KB

# %% [markdown]
# # Exercise 7 (2 points)
#
# Print only the `occupation` column.

# %%
users['occupation']
# Out:
# user_id
# 1         technician
# 2              other
# 3             writer
# 4         technician
# 5              other
#            ...
# 939          student
# 940    administrator
# 941          student
# 942        librarian
# 943          student
# Name: occupation, Length: 943, dtype: str

# %% [markdown]
# # Exercise 8 (2 points)
#
# How many different occupations are in this dataset?

# %%
#use the unique property to get the distinct value count of the occupation column.
users['occupation'].nunique()
# Out:
# 21

# %% [markdown]
# # Exercise 9 (2 points)
#
# What is the most frequent occupation?

# %%
users["occupation"].value_counts(normalize=True)
# Out:
# occupation
# student          0.207847
# other            0.111347
# educator         0.100742
# administrator    0.083775
# engineer         0.071050
# programmer       0.069989
# librarian        0.054083
# writer           0.047720
# executive        0.033934
# scientist        0.032874
# artist           0.029692
# technician       0.028632
# marketing        0.027572
# entertainment    0.019088
# healthcare       0.016967
# retired          0.014846
# lawyer           0.012725
# salesman         0.012725
# none             0.009544
# homemaker        0.007423
# doctor           0.007423
# Name: proportion, dtype: float64

# %% [markdown]
# # Exercise 10 (2 points)
#
# Summarize the `users` data-frame.

# %%
users.describe()
# Out:
#               age
# count  943.000000
# mean    34.051962
# std     12.192740
# min      7.000000
# 25%     25.000000
# 50%     31.000000
# 75%     43.000000
# max     73.000000

# %% [markdown]
# # Exercise 11 (2 points)
#
# Summarize all the columns from the `users` data-frame.

# %%
users.describe(include='all')
# Out:
#                age gender occupation zip_code
# count   943.000000    943        943      943
# unique         NaN      2         21      795
# top            NaN      M    student    55414
# freq           NaN    670        196        9
# mean     34.051962    NaN        NaN      NaN
# std      12.192740    NaN        NaN      NaN
# min       7.000000    NaN        NaN      NaN
# 25%      25.000000    NaN        NaN      NaN
# 50%      31.000000    NaN        NaN      NaN
# 75%      43.000000    NaN        NaN      NaN
# max      73.000000    NaN        NaN      NaN

# %% [markdown]
# # Exercise 12 (2 points)
#
# What is the mean `age` of users?

# %%
mean_age = users['age'].mean()
print(mean_age)
# Out:
# 34.05196182396607

# %% [markdown]
# # Exercise 13 (2 points)
#
# Report the mean `age` of female and male users.

# %%
gender_mean_age = users.groupby('gender')['age'].mean()
print(gender_mean_age)
# Out:
# gender
# F    33.813187
# M    34.149254
# Name: age, dtype: float64
